# %%
import pandas as pd
import matplotlib.pyplot as plt

# %%
df = pd.read_csv("FM_housing.csv",encoding='latin1')
df.head()
# Out:
#   List Number                              Agency Name  \
# 0     18-5119             Modern Market Realtors (mmr)
# 1     18-5120                     Beyond Realty (byrt)
# 2     18-5122               RE/MAX Legacy Realty (leg)
# 3     18-5124               Castle Realty, Inc. (CAST)
# 4     18-6428  KW Inspire Realty Keller Williams (kwr)
#
#             Listing Agent             Book Section  Start Date Pended Date  \
# 0          Shannon Barnum  Single Family Residence  2018-09-13  2018-09-17
# 1            Mike Gillund  Single Family Residence  2018-09-12  2018-09-30
# 2           Gary S Gonser              Condominium  2018-09-07  2018-10-05
# 3  Kimberly Krueger Tehan  Single Family Residence  2018-09-13  2018-11-13
# 4            Jason Harmon                Twinhomes  2018-12-27  2019-03-23
#
#     Sold Date  List Price  Sold Price      City  ... Sold Price Per/SqFt  \
# 0  2018-11-09    214900.0      214900     Fargo  ...              182.74
# ...

# %%
df.describe()
# Out:
#          List Price    Sold Price   Postal Code      Geo Lat      Geo Lon  \
# count  6.179000e+03  6.179000e+03   6177.000000  6179.000000  6179.000000
# mean   2.533538e+05  2.513034e+05  57757.210458    46.844453   -96.828954
# std    1.137121e+05  1.109854e+05    636.275290     0.033674     0.059358
# min    1.800000e+04  1.750000e+04  56560.000000    46.661985   -96.954310
# 25%    1.850000e+05  1.840000e+05  58078.000000    46.821830   -96.886409
# 50%    2.280000e+05  2.270000e+05  58102.000000    46.842373   -96.817116
# 75%    2.920000e+05  2.915650e+05  58104.000000    46.865090   -96.781915
# max    2.250000e+06  1.890000e+06  58104.000000    47.004004   -96.694109
#
#        Total SqFt.   Year Built  Total Bedrooms  Total Bathrooms  \
# count  6179.000000  6179.000000     6179.000000      6179.000000
# mean   2315.055108  1986.991746        3.458488         2.407509
# std     824.133886    66.075433        0.909831         0.787147
# ...

# %%
df.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 6179 entries, 0 to 6178
# Data columns (total 44 columns):
#  #   Column                       Non-Null Count  Dtype
# ---  ------                       --------------  -----
#  0   List Number                  6179 non-null   object
#  1   Agency Name                  6179 non-null   object
#  2   Listing Agent                6179 non-null   object
#  3   Book Section                 6179 non-null   object
#  4   Start Date                   6179 non-null   object
#  5   Pended Date                  6178 non-null   object
#  6   Sold Date                    6179 non-null   object
#  7   List Price                   6179 non-null   float64
#  8   Sold Price                   6179 non-null   int64
#  9   City                         6179 non-null   object
#  10  State/Province               6179 non-null   object
#  11  Postal Code                  6177 non-null   float64
#  12  Geo Lat                      6179 non-null   float64
# ...

# %%
df.nunique()
# Out:
# List Number                    6179
# Agency Name                      78
# Listing Agent                   566
# Book Section                      6
# Start Date                      846
# Pended Date                     817
# Sold Date                       519
# List Price                     1478
# Sold Price                     2020
# City                              3
# State/Province                    2
# Postal Code                       5
# Geo Lat                        5772
# Geo Lon                        5762
# Total SqFt.                    2000
# Year Built                      136
# Style                             7
# Total Bedrooms                    9
# Total Bathrooms                   8
# Total Full Baths                  6
# Total Half Baths                  4
# Total 3/4 Baths                   4
# Garage Type                       2
# Garage Stalls                     9
# Gen Tax                        5259
# Subdivision                    2183
# ...

# %%
df = df.drop(['Lake'],axis=1)
df = df.drop(['Total Half Baths'], axis=1)
df = df.drop(['Total 3/4 Baths'], axis=1)

# %%
df.isnull().sum()
# Out:
# List Number                       0
# Agency Name                       0
# Listing Agent                     0
# Book Section                      0
# Start Date                        0
# Pended Date                       1
# Sold Date                         0
# List Price                        0
# Sold Price                        0
# City                              0
# State/Province                    0
# Postal Code                       2
# Geo Lat                           0
# Geo Lon                           0
# Total SqFt.                       0
# Year Built                        0
# Style                             5
# Total Bedrooms                    0
# Total Bathrooms                   0
# Total Full Baths                992
# Garage Type                     101
# Garage Stalls                     0
# Gen Tax                           0
# Subdivision                      13
# Public Remarks                   31
# Parcel No.                        1
# ...

# %%
df.dropna(inplace=True)

# %%
df['Style'] = df['Style'].replace({'Bi Level': '2 Story', '4 Level': '4 Story', '3 Level': '3 Story'})

# %%
df.nunique()
# Out:
# List Number                    2854
# Agency Name                      62
# Listing Agent                   427
# Book Section                      6
# Start Date                      728
# Pended Date                     730
# Sold Date                       485
# List Price                      874
# Sold Price                     1167
# City                              3
# State/Province                    2
# Postal Code                       5
# Geo Lat                        2763
# Geo Lon                        2755
# Total SqFt.                    1358
# Year Built                      131
# Style                             5
# Total Bedrooms                    7
# Total Bathrooms                   7
# Total Full Baths                  6
# Garage Type                       2
# Garage Stalls                     9
# Gen Tax                        2601
# Subdivision                    1389
# Public Remarks                 2821
# Parcel No.                     2828
# ...

# %%
plt.figure(figsize=(20, 20))
df.hist()
plt.subplots_adjust(hspace=1.0, wspace=1.0)

# %%
df.to_csv("fm_housing_clean.csv", index=False)
